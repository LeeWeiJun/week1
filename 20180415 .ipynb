# %%
from skimage import io,data

img=io.imread('2.jpg')
rows,cols,dims=img.shape
img2=img

for i in range(0,rows):
    for j in range(0,cols):
            img2[i,j,1]=0.7*img[i,j,1]
            img2[i,j,2]=0.7*img[i,j,2]
            
io.imshow(img2)
io.show()

io.imsave('3.jpg',img2)
# Out:
# C:\Users\Win7\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
